# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import plotly.colors as colors
pio.templates.default = "plotly_white"

# %%
data = pd.read_csv("data/raw/sample_superstore.csv",encoding="latin-1")

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# descriptive 
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# converting the data from object to date
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
# converting with month
data['Order Month'] = data['Order Date'].dt.month

# converting with year
data['Order year'] = data['Order Date'].dt.year

# converting order day of week
data['Order Day of Week'] = data['Order Date'].dt.dayofweek

# %%
# Monthly sales analysis
sales_by_month = data.groupby('Order Month')['Sales'].sum().reset_index()
sales_by_month
# Out:
#     Order Month        Sales
# 0             1   94924.8356
# 1             2   59751.2514
# 2             3  205005.4888
# 3             4  137762.1286
# 4             5  155028.8117
# 5             6  152718.6793
# 6             7  147238.0970
# 7             8  159044.0630
# 8             9  307649.9457
# 9            10  200322.9847
# 10           11  352461.0710
# 11           12  325293.5035

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(sales_by_month['Order Month'], sales_by_month['Sales'], marker='o')
plt.title("Monthly Sales Analysis")
plt.xlabel("Order Month")
plt.ylabel("Sales")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# sales by category
sales_by_category = data.groupby('Category')['Sales'].sum().reset_index()
sales_by_category
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
# visualize for sales by category

plt.figure(figsize=(10, 6))
plt.plot(sales_by_category['Category'], sales_by_category['Sales'], marker='o')
plt.title("Category Sales Analysis")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()

# %%
# pie chart visualization
plt.figure(figsize=(8, 7))
plt.pie(
    sales_by_category['Sales'],
    labels=sales_by_category['Category'],
    autopct='%1.1f%%',  # Show percentages with 1 decimal
    startangle=140,     # Rotate start angle
    shadow=True         # Optional shadow for 3D effect
)

plt.title("Category Sales Distribution")
plt.axis('equal')  # Ensures the pie is a circle
plt.tight_layout()
plt.show()

# %%
# sales by sub category 
sales_by_subcategory = data.groupby('Sub-Category')['Sales'].sum().reset_index()
sales_by_subcategory
# Out:
#    Sub-Category        Sales
# 0   Accessories  167380.3180
# 1    Appliances  107532.1610
# 2           Art   27118.7920
# 3       Binders  203412.7330
# 4     Bookcases  114879.9963
# 5        Chairs  328449.1030
# 6       Copiers  149528.0300
# 7     Envelopes   16476.4020
# 8     Fasteners    3024.2800
# 9   Furnishings   91705.1640
# 10       Labels   12486.3120
# 11     Machines  189238.6310
# 12        Paper   78479.2060
# 13       Phones  330007.0540
# 14      Storage  223843.6080
# 15     Supplies   46673.5380
# 16       Tables  206965.5320

# %%
# visualization for sales by sub category
plt.figure(figsize=(12, 6))
plt.bar(sales_by_subcategory['Sub-Category'], sales_by_subcategory['Sales'], color='skyblue')
plt.title("Sales by Sub-Category")
plt.xlabel("Sub-Category")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# profit by month
profit_by_month = data.groupby('Order Month')['Profit'].sum().reset_index()
profit_by_month
# Out:
#     Order Month      Profit
# 0             1   9134.4461
# 1             2  10294.6107
# 2             3  28594.6872
# 3             4  11587.4363
# 4             5  22411.3078
# 5             6  21285.7954
# 6             7  13832.6648
# 7             8  21776.9384
# 8             9  36857.4753
# 9            10  31784.0413
# 10           11  35468.4265
# 11           12  43369.1919

# %%
# visualization for profit by month
plt.figure(figsize=(12, 6))
plt.bar(profit_by_month['Order Month'], profit_by_month['Profit'], color='red')
plt.title("Profit by Month")
plt.xlabel("Month")
plt.ylabel("Profit")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# visualize in line 

plt.figure(figsize=(10, 6))
plt.plot(profit_by_month['Order Month'], profit_by_month['Profit'], marker='o')
plt.title("Profit By Month analysis")
plt.xlabel("Order Month")
plt.ylabel("Profit")
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
# profit by category
profit_by_category = data.groupby('Category')['Profit'].sum().reset_index()
profit_by_category
# Out:
#           Category       Profit
# 0        Furniture   18451.2728
# 1  Office Supplies  122490.8008
# 2       Technology  145454.9481

# %%
# visualize the profit by category
plt.figure(figsize=(8, 7))
plt.pie(
    profit_by_category['Profit'],
    labels=profit_by_category['Category'],
    autopct='%1.1f%%',  # Show percentages with 1 decimal
    startangle=140,     # Rotate start angle
    shadow=True         # Optional shadow for 3D effect
)

plt.title("Category Profit ")
plt.axis('equal')  # Ensures the pie is a circle
plt.tight_layout()
plt.show()
